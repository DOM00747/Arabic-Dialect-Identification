# %%
import pandas as pd
final_df = pd.read_csv('final_df.csv' , lineterminator='\n')
final_df.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2                    @KanaanRema مبين من كلامه خليجي
# 3         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺

# %%
final_df.shape
# Out:
# (458197, 3)

# %%
final_df.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2                    @KanaanRema مبين من كلامه خليجي
# 3         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺

# %%
import pyarabic.araby as araby
import pyarabic.number as number

# %%
final_df.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0   @Nw8ieJUwaCAAreT لكن بالنهاية .. ينتفض .. يغير .
# 1  @7zNqXP0yrODdRjK يعني هذا محسوب على البشر .. ح...
# 2                    @KanaanRema مبين من كلامه خليجي
# 3         @HAIDER76128900 يسلملي مرورك وروحك الحلوه💐
# 4                 @hmo2406 وين هل الغيبه  اخ محمد 🌸🌺

# %%
import re

def remove_usernames_links(tweet):
    tweet = re.sub('@[^\s]+','',tweet)
    tweet = re.sub('http[^\s]+','',tweet)
    return tweet
final_df['tweet'] = final_df['tweet'].apply(remove_usernames_links)

# %%
final_df.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0                    لكن بالنهاية .. ينتفض .. يغير .
# 1   يعني هذا محسوب على البشر .. حيونه ووحشيه .. و...
# 2                                مبين من كلامه خليجي
# 3                         يسلملي مرورك وروحك الحلوه💐
# 4                          وين هل الغيبه  اخ محمد 🌸🌺

# %%
import re

def remove_emoji(tweet):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', tweet)

# %%
final_df['tweet'] = final_df['tweet'].apply(remove_emoji)

# %%
final_df.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0                    لكن بالنهاية .. ينتفض .. يغير .
# 1   يعني هذا محسوب على البشر .. حيونه ووحشيه .. و...
# 2                                مبين من كلامه خليجي
# 3                          يسلملي مرورك وروحك الحلوه
# 4                            وين هل الغيبه  اخ محمد

# %%
final_df.to_csv(r'clean_final_df.csv' , index = False)

# %%
final_df.shape
# Out:
# (458197, 3)

# %%
data = pd.read_csv('clean_final_df.csv' , lineterminator='\n')

# %%
data.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0                    لكن بالنهاية .. ينتفض .. يغير .
# 1   يعني هذا محسوب على البشر .. حيونه ووحشيه .. و...
# 2                                مبين من كلامه خليجي
# 3                          يسلملي مرورك وروحك الحلوه
# 4                            وين هل الغيبه  اخ محمد

# %%
pip install --user -U nltk
# Out:
# Requirement already satisfied: nltk in /Users/mohamedrashad/.local/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tqdm in /Users/mohamedrashad/miniforge3/envs/ml/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: click in /Users/mohamedrashad/miniforge3/envs/ml/lib/python3.9/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/mohamedrashad/miniforge3/envs/ml/lib/python3.9/site-packages (from nltk) (2021.11.10)
# Requirement already satisfied: joblib in /Users/mohamedrashad/miniforge3/envs/ml/lib/python3.9/site-packages (from nltk) (1.1.0)
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the '/Users/mohamedrashad/miniforge3/envs/ml/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
data = pd.read_csv('clean_final_df.csv' , lineterminator='\n')

# %%
data.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet
# 0                    لكن بالنهاية .. ينتفض .. يغير .
# 1   يعني هذا محسوب على البشر .. حيونه ووحشيه .. و...
# 2                                مبين من كلامه خليجي
# 3                          يسلملي مرورك وروحك الحلوه
# 4                            وين هل الغيبه  اخ محمد

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/mohamedrashad/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mohamedrashad/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords


data['tokenized_tweets'] = data.apply(lambda row: nltk.word_tokenize(row['tweet']), axis=1)
sw = stopwords.words('arabic')
data['stopped_tweets'] = [i for i in data['tokenized_tweets'] if not i in sw]

#iterate over the tokenized_tweets column
len_tokens = []
word_tokens = data['tokenized_tweets']
for i in range(len(word_tokens)):
  len_tokens.append(len(word_tokens[i]))

data['n_tokens'] = len_tokens

# %%
data.head()
# Out:
#                     id dialect  \
# 0  1175358310087892992      IQ
# 1  1175416117793349632      IQ
# 2  1175450108898565888      IQ
# 3  1175471073770573824      IQ
# 4  1175496913145217024      IQ
#
#                                                tweet  \
# 0                    لكن بالنهاية .. ينتفض .. يغير .
# 1   يعني هذا محسوب على البشر .. حيونه ووحشيه .. و...
# 2                                مبين من كلامه خليجي
# 3                          يسلملي مرورك وروحك الحلوه
# 4                            وين هل الغيبه  اخ محمد
#
#                                     tokenized_tweets  \
# 0            [لكن, بالنهاية, .., ينتفض, .., يغير, .]
# 1  [يعني, هذا, محسوب, على, البشر, .., حيونه, ووحش...
# 2                           [مبين, من, كلامه, خليجي]
# 3                     [يسلملي, مرورك, وروحك, الحلوه]
# 4                        [وين, هل, الغيبه, اخ, محمد]
#
#                                       stopped_tweets  n_tokens
# 0            [لكن, بالنهاية, .., ينتفض, .., يغير, .]         7
# 1  [يعني, هذا, محسوب, على, البشر, .., حيونه, ووحش...        18
# 2                           [مبين, من, كلامه, خليجي]         4
# 3                     [يسلملي, مرورك, وروحك, الحلوه]         4
# 4                        [وين, هل, الغيبه, اخ, محمد]         5

# %%
#importing libraries
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import nltk
import re
import string
import nltk 
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %%
X_train , X_test , y_train , y_test = train_test_split(data['tweet'] , data['dialect'] , test_size = 0.25 , random_state = 53)

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.fit_transform(y_test)

# %%
tf_idf = TfidfVectorizer(decode_error='replace', encoding='utf-8')
X_train_tf = tf_idf.fit_transform(X_train.values.astype('U'))
X_train_tf = tf_idf.transform(X_train.values.astype('U'))
print("n_samples: %d, n_features: %d" % X_train_tf.shape)
X_test_tf = tf_idf.transform(X_test.values.astype('U'))
print("n_samples: %d, n_features: %d" % X_test_tf.shape)
# Out:
# n_samples: 343647, n_features: 438347
# n_samples: 114550, n_features: 438347

# %%
svm_clf = svm.SVC(C=1.0, kernel = 'linear' ,verbose=True, max_iter=5000 ,gamma = 'auto')
svm_clf.fit(X_train_tf , y_train)
prediction_svm = svm_clf.predict(X_test_tf)
print("Accuracy : " , accuracy_score(prediction_svm , y_test)*100)
print("F1 Score : ",f1_score(y_test, prediction_svm, average='macro'))
# Out:
# [LibSVM]....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8280.334293, rho = -0.001238
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6252.379155, rho = -0.135091
# nSV = 9941, nBSV = 7808
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6845.244339, rho = 0.067915
# nSV = 9974, nBSV = 9688
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6520.254799, rho = -0.013964
# nSV = 9966, nBSV = 8568
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7634.651062, rho = 0.005508
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8328.698736, rho = 0.021393
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6313.529456, rho = -0.003852
# nSV = 9981, nBSV = 8341
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7444.903979, rho = 0.049956
# nSV = 9998, nBSV = 9998
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4662.399526, rho = -0.374372
# nSV = 9017, nBSV = 4911
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8098.945937, rho = 0.011345
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7736.126029, rho = -0.211037
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8315.533397, rho = -0.023571
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8028.209427, rho = 0.024837
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5448.318328, rho = -0.228377
# nSV = 9579, nBSV = 6355
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6470.097765, rho = -0.025160
# nSV = 9973, nBSV = 8515
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4723.340592, rho = -0.414979
# nSV = 9033, nBSV = 5089
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6635.330430, rho = -0.098518
# nSV = 9980, nBSV = 8880
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5851.917272, rho = -0.481370
# nSV = 9658, nBSV = 7000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6591.454634, rho = -0.169758
# nSV = 9982, nBSV = 8640
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4469.136660, rho = 0.394856
# nSV = 8919, nBSV = 4525
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5347.346615, rho = 0.474346
# nSV = 9315, nBSV = 5942
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4636.923146, rho = 0.390843
# nSV = 9018, nBSV = 4845
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4743.878768, rho = 0.435816
# nSV = 9054, nBSV = 4949
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -3799.176232, rho = 0.187692
# nSV = 8377, nBSV = 3733
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4241.493231, rho = 0.319763
# nSV = 8777, nBSV = 4344
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -3932.022925, rho = -0.067441
# nSV = 8397, nBSV = 4019
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -3957.836773, rho = 0.242715
# nSV = 8568, nBSV = 3924
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7597.214836, rho = 0.042798
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7878.108743, rho = -0.020763
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7846.391941, rho = 0.014768
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5055.458222, rho = -0.261441
# nSV = 9349, nBSV = 5671
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6349.558852, rho = -0.060863
# nSV = 9965, nBSV = 8185
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4390.519713, rho = -0.436322
# nSV = 8807, nBSV = 4529
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6770.642851, rho = -0.070729
# nSV = 9991, nBSV = 9067
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7531.421407, rho = -0.049116
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7611.933688, rho = -0.014252
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6583.483306, rho = -0.220719
# nSV = 9919, nBSV = 8498
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8075.783903, rho = -0.056011
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5549.327468, rho = -0.507958
# nSV = 9352, nBSV = 6351
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6929.375899, rho = -0.145097
# nSV = 9982, nBSV = 9312
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -8188.857799, rho = -0.034286
# nSV = 10000, nBSV = 10000
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5405.618931, rho = -0.269711
# nSV = 9564, nBSV = 6281
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6277.950766, rho = -0.061355
# nSV = 9969, nBSV = 8105
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4575.790648, rho = -0.436310
# nSV = 8969, nBSV = 4849
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7068.405637, rho = -0.038228
# nSV = 9996, nBSV = 9834
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5297.893176, rho = -0.311387
# nSV = 9454, nBSV = 6037
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -6522.706768, rho = -0.103216
# nSV = 9967, nBSV = 8556
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4632.972957, rho = -0.502470
# nSV = 8918, nBSV = 4832
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -7293.123459, rho = -0.096438
# nSV = 9998, nBSV = 9998
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4762.653682, rho = 0.161323
# nSV = 9216, nBSV = 5219
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -3822.814894, rho = -0.240694
# nSV = 8350, nBSV = 3817
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4589.853679, rho = 0.041962
# nSV = 9042, nBSV = 4977
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -4243.502755, rho = -0.380572
# nSV = 8680, nBSV = 4352
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -5550.742641, rho = -0.095794
# nSV = 9730, nBSV = 6631
# ....WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 5000
# obj = -3987.983734, rho = 0.283998
# nSV = 8556, nBSV = 4041
# Total nSV = 253133
# /Users/mohamedrashad/miniforge3/envs/ml/lib/python3.9/site-packages/sklearn/svm/_base.py:284: ConvergenceWarning: Solver terminated early (max_iter=5000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy :  47.94325621999127
# F1 Score :  0.46158415411441944

# %%
import pickle
# save the classifier
with open('svm.pkl', 'wb') as fid:
    pickle.dump(svm_clf, fid)
